# %% [markdown]
# # ASSIGNMENT 3 - PIZZA SALES ANALYSIS🍕

# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
#Import dataframe 1
df1 = pd.read_csv('pizzas.csv', encoding='latin-1')

df1
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
#Get info on dataframe 1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_id       96 non-null     object
#  1   pizza_type_id  96 non-null     object
#  2   size           96 non-null     object
#  3   price          96 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 3.1+ KB

# %%
#Count the value count of pizza type id column of the dataframe
df1["pizza_type_id"].value_counts()
# Out:
# pizza_type_id
# the_greek       5
# bbq_ckn         3
# peppr_salami    3
# spinach_fet     3
# spin_pesto      3
# mexicana        3
# mediterraneo    3
# ital_veggie     3
# green_garden    3
# four_cheese     3
# five_cheese     3
# spinach_supr    3
# spicy_ital      3
# soppressata     3
# sicilian        3
# prsc_argla      3
# ital_supr       3
# cali_ckn        3
# calabrese       3
# pepperoni       3
# pep_msh_pep     3
# napolitana      3
# ital_cpcllo     3
# hawaiian        3
# classic_dlx     3
# big_meat        3
# thai_ckn        3
# southw_ckn      3
# ckn_pesto       3
# ckn_alfredo     3
# veggie_veg      3
# brie_carre      1
# Name: count, dtype: int64

# %%
#Import dataframe 2
df2 = pd.read_csv('pizza_types.csv', encoding='latin-1')

df2
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
#Get info on dataframe 2
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_type_id  32 non-null     object
#  1   name           32 non-null     object
#  2   category       32 non-null     object
#  3   ingredients    32 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
#Get a description on the dataframe
df2.describe()
# Out:
#        pizza_type_id                        name category  \
# count             32                          32       32
# unique            32                          32        4
# top          bbq_ckn  The Barbecue Chicken Pizza  Supreme
# freq               1                           1        9
#
#                                               ingredients
# count                                                  32
# unique                                                 32
# top     Barbecued Chicken, Red Peppers, Green Peppers,...
# freq                                                    1

# %%
#Get the value counts of the category column of the dataframe
df2["category"].value_counts()
# Out:
# category
# Supreme    9
# Veggie     9
# Classic    8
# Chicken    6
# Name: count, dtype: int64

# %%
#Import dataframe 3
df3 = pd.read_csv('orders.csv', encoding='latin-1')

df3
# Out:
#        order_id        date      time
# 0             1  2015-01-01  11:38:36
# 1             2  2015-01-01  11:57:40
# 2             3  2015-01-01  12:12:28
# 3             4  2015-01-01  12:16:31
# 4             5  2015-01-01  12:21:30
# ...         ...         ...       ...
# 21345     21346  2015-12-31  20:51:07
# 21346     21347  2015-12-31  21:14:37
# 21347     21348  2015-12-31  21:23:10
# 21348     21349  2015-12-31  22:09:54
# 21349     21350  2015-12-31  23:02:05
#
# [21350 rows x 3 columns]

# %%
#Get info on the dataframe
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21350 entries, 0 to 21349
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  21350 non-null  int64
#  1   date      21350 non-null  object
#  2   time      21350 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 500.5+ KB

# %%
#Get the value counts of the date column of the data frame
df3["date"].value_counts()
# Out:
# date
# 2015-11-27    115
# 2015-11-26    113
# 2015-10-15    107
# 2015-07-04    105
# 2015-05-15     94
#              ...
# 2015-03-22     37
# 2015-02-22     37
# 2015-12-27     35
# 2015-12-30     32
# 2015-12-29     27
# Name: count, Length: 358, dtype: int64

# %%
#Get the value counts of the time column of the data frame
df3["time"].value_counts()
# Out:
# time
# 18:49:37    6
# 18:49:15    5
# 13:05:06    5
# 20:05:12    5
# 17:50:15    5
#            ..
# 12:11:39    1
# 16:52:12    1
# 15:29:05    1
# 12:31:54    1
# 22:09:54    1
# Name: count, Length: 16382, dtype: int64

# %%
#Get the value counts of the order id column of the data frame
df3["order_id"].value_counts()
# Out:
# order_id
# 1        1
# 14241    1
# 14239    1
# 14238    1
# 14237    1
#         ..
# 7116     1
# 7115     1
# 7114     1
# 7113     1
# 21350    1
# Name: count, Length: 21350, dtype: int64

# %%
#Import dataframe 4
df4 = pd.read_csv('order_details.csv', encoding='latin-1')

df4
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
df4.groupby("pizza_id").sum().sort_values("quantity",ascending=False).head(5)
# Out:
#                order_details_id  order_id  quantity
# pizza_id
# big_meat_s             44373219  19533329      1914
# thai_ckn_l             34070922  14996768      1410
# five_cheese_l          31911486  14048981      1409
# four_cheese_l          31048657  13666613      1316
# classic_dlx_m          29074088  12799554      1181

# %%
#Get info on the dataframe
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
#Get the value counts of the order id column of the data frame
df4["order_id"].value_counts()
# Out:
# order_id
# 18845    21
# 10760    21
# 18280    15
# 21158    15
# 17464    15
#          ..
# 10351     1
# 10355     1
# 10357     1
# 10360     1
# 21350     1
# Name: count, Length: 21350, dtype: int64

# %%
#Get the value counts of the pizza id column of the data frame
df4["pizza_id"].value_counts()
# Out:
# pizza_id
# big_meat_s        1811
# thai_ckn_l        1365
# five_cheese_l     1359
# four_cheese_l     1273
# classic_dlx_m     1159
#                   ...
# mexicana_s         160
# calabrese_s         99
# ckn_alfredo_s       96
# green_garden_l      94
# the_greek_xxl       28
# Name: count, Length: 91, dtype: int64

# %%
#Merge df1 and df2 on the pizza type id column. Outer join was used
df5 = pd.merge(df1, df2, on= 'pizza_type_id', how= 'outer')

df5
# Out:
#          pizza_id pizza_type_id size  price  \
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      big_meat_s      big_meat    S  12.00
# 4      big_meat_m      big_meat    M  16.00
# ..            ...           ...  ...    ...
# 91   the_greek_xl     the_greek   XL  25.50
# 92  the_greek_xxl     the_greek  XXL  35.95
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
#                                  name category  \
# 0          The Barbecue Chicken Pizza  Chicken
# 1          The Barbecue Chicken Pizza  Chicken
# 2          The Barbecue Chicken Pizza  Chicken
# 3                  The Big Meat Pizza  Classic
# 4                  The Big Meat Pizza  Classic
# ..                                ...      ...
# 91                    The Greek Pizza  Classic
# ...

# %%
#Get info on the merged dataframe
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_id       96 non-null     object
#  1   pizza_type_id  96 non-null     object
#  2   size           96 non-null     object
#  3   price          96 non-null     float64
#  4   name           96 non-null     object
#  5   category       96 non-null     object
#  6   ingredients    96 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 5.4+ KB

# %%
#Merge df3 and df4 on the order id column. Outer join was used
df6 = pd.merge(df3,df4, on= 'order_id', how= 'outer')

df6
# Out:
#        order_id        date      time  order_details_id       pizza_id  \
# 0             1  2015-01-01  11:38:36                 1     hawaiian_m
# 1             2  2015-01-01  11:57:40                 2  classic_dlx_m
# 2             2  2015-01-01  11:57:40                 3  five_cheese_l
# 3             2  2015-01-01  11:57:40                 4    ital_supr_l
# 4             2  2015-01-01  11:57:40                 5     mexicana_m
# ...         ...         ...       ...               ...            ...
# 48615     21348  2015-12-31  21:23:10             48616  ckn_alfredo_m
# 48616     21348  2015-12-31  21:23:10             48617  four_cheese_l
# 48617     21348  2015-12-31  21:23:10             48618   napolitana_s
# 48618     21349  2015-12-31  22:09:54             48619     mexicana_l
# 48619     21350  2015-12-31  23:02:05             48620      bbq_ckn_s
#
#        quantity
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...

# %%
#Get info on the merged dataframe
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          48620 non-null  int64
#  1   date              48620 non-null  object
#  2   time              48620 non-null  object
#  3   order_details_id  48620 non-null  int64
#  4   pizza_id          48620 non-null  object
#  5   quantity          48620 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.2+ MB

# %%
#Combine the two merged dataframes into one
merged_data = pd.merge(df5, df6, on= 'pizza_id', how= 'outer')

merged_data
# Out:
#            pizza_id pizza_type_id size  price  \
# 0         bbq_ckn_l       bbq_ckn    L  20.75
# 1         bbq_ckn_l       bbq_ckn    L  20.75
# 2         bbq_ckn_l       bbq_ckn    L  20.75
# 3         bbq_ckn_l       bbq_ckn    L  20.75
# 4         bbq_ckn_l       bbq_ckn    L  20.75
# ...             ...           ...  ...    ...
# 48620  veggie_veg_s    veggie_veg    S  12.00
# 48621  veggie_veg_s    veggie_veg    S  12.00
# 48622  veggie_veg_s    veggie_veg    S  12.00
# 48623  veggie_veg_s    veggie_veg    S  12.00
# 48624  veggie_veg_s    veggie_veg    S  12.00
#
#                                     name category  \
# 0             The Barbecue Chicken Pizza  Chicken
# 1             The Barbecue Chicken Pizza  Chicken
# 2             The Barbecue Chicken Pizza  Chicken
# 3             The Barbecue Chicken Pizza  Chicken
# 4             The Barbecue Chicken Pizza  Chicken
# ...                                  ...      ...
# 48620  The Vegetables + Vegetables Pizza   Veggie
# ...

# %%
#Get info on the combined dataframe to check for null values
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48625 entries, 0 to 48624
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pizza_id          48625 non-null  object
#  1   pizza_type_id     48625 non-null  object
#  2   size              48625 non-null  object
#  3   price             48625 non-null  float64
#  4   name              48625 non-null  object
#  5   category          48625 non-null  object
#  6   ingredients       48625 non-null  object
#  7   order_id          48620 non-null  float64
#  8   date              48620 non-null  object
#  9   time              48620 non-null  object
#  10  order_details_id  48620 non-null  float64
#  11  quantity          48620 non-null  float64
# dtypes: float64(4), object(8)
# memory usage: 4.5+ MB

# %%
#Drop null values from the dataframe
merged_data = merged_data.dropna()

merged_data
# Out:
#            pizza_id pizza_type_id size  price  \
# 0         bbq_ckn_l       bbq_ckn    L  20.75
# 1         bbq_ckn_l       bbq_ckn    L  20.75
# 2         bbq_ckn_l       bbq_ckn    L  20.75
# 3         bbq_ckn_l       bbq_ckn    L  20.75
# 4         bbq_ckn_l       bbq_ckn    L  20.75
# ...             ...           ...  ...    ...
# 48620  veggie_veg_s    veggie_veg    S  12.00
# 48621  veggie_veg_s    veggie_veg    S  12.00
# 48622  veggie_veg_s    veggie_veg    S  12.00
# 48623  veggie_veg_s    veggie_veg    S  12.00
# 48624  veggie_veg_s    veggie_veg    S  12.00
#
#                                     name category  \
# 0             The Barbecue Chicken Pizza  Chicken
# 1             The Barbecue Chicken Pizza  Chicken
# 2             The Barbecue Chicken Pizza  Chicken
# 3             The Barbecue Chicken Pizza  Chicken
# 4             The Barbecue Chicken Pizza  Chicken
# ...                                  ...      ...
# 48620  The Vegetables + Vegetables Pizza   Veggie
# ...

# %% [markdown]
# ##### After dropping the null values, we check to see if it was successful and there are no null values in the dataframe

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48620 entries, 0 to 48624
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pizza_id          48620 non-null  object
#  1   pizza_type_id     48620 non-null  object
#  2   size              48620 non-null  object
#  3   price             48620 non-null  float64
#  4   name              48620 non-null  object
#  5   category          48620 non-null  object
#  6   ingredients       48620 non-null  object
#  7   order_id          48620 non-null  float64
#  8   date              48620 non-null  object
#  9   time              48620 non-null  object
#  10  order_details_id  48620 non-null  float64
#  11  quantity          48620 non-null  float64
# dtypes: float64(4), object(8)
# memory usage: 4.8+ MB

# %%
null_counts = merged_data.isna().sum()
print(null_counts)
# Out:
# pizza_id            0
# pizza_type_id       0
# size                0
# price               0
# name                0
# category            0
# ingredients         0
# order_id            0
# date                0
# time                0
# order_details_id    0
# quantity            0
# dtype: int64

# %%
has_null = merged_data.isna().any()
print(has_null)
# Out:
# pizza_id            False
# pizza_type_id       False
# size                False
# price               False
# name                False
# category            False
# ingredients         False
# order_id            False
# date                False
# time                False
# order_details_id    False
# quantity            False
# dtype: bool

# %% [markdown]
# ## 💡 QUESTION 1

# %%
#Calculate the total revenue made and a revenue column to the dataframe
merged_data['revenue'] = merged_data['quantity'] * merged_data['price']

total_revenue = merged_data['revenue'].sum()
print('Total revenue:', total_revenue)
# Out:
# Total revenue: 817860.0499999999

# %% [markdown]
# ## 💡 QUESTION 2

# %%
#Count the total quantity 
total_quantity_counts = merged_data['quantity'].value_counts()

total_quantity_counts
# Out:
# quantity
# 1.0    47693
# 2.0      903
# 3.0       21
# 4.0        3
# Name: count, dtype: int64

# %%
#Calculate the total quantity sold
total_quantity = merged_data['quantity'].sum()

print('Total Quantity:', total_quantity)
# Out:
# Total Quantity: 49574.0

# %% [markdown]
# ## 💡QUESTION 3

# %%
#Find the total orders
total_orders = len(merged_data['order_id'].unique())

print('The total orders:', total_orders)
# Out:
# The total orders: 21350

# %% [markdown]
# ## 💡 QUESTION 4

# %%
#Count how many of each pizza type are being bought
pizza_types_counts = merged_data['name'].value_counts()

pizza_types_counts
# Out:
# name
# The Classic Deluxe Pizza                      2416
# The Barbecue Chicken Pizza                    2372
# The Hawaiian Pizza                            2370
# The Pepperoni Pizza                           2369
# The Thai Chicken Pizza                        2315
# The California Chicken Pizza                  2302
# The Spicy Italian Pizza                       1887
# The Sicilian Pizza                            1887
# The Southwest Chicken Pizza                   1885
# The Four Cheese Pizza                         1850
# The Italian Supreme Pizza                     1849
# The Big Meat Pizza                            1811
# The Vegetables + Vegetables Pizza             1510
# The Mexicana Pizza                            1456
# The Napolitana Pizza                          1451
# The Spinach and Feta Pizza                    1432
# The Prosciutto and Arugula Pizza              1428
# The Pepper Salami Pizza                       1422
# ...

# %%
#Find the distinct number of pizza types they sell
num_pizza_types_counts = len(merged_data['name'].unique())

print(f"They sell {num_pizza_types_counts} pizza types")
# Out:
# They sell 32 pizza types

# %%
#Get a description for the dataframe
merged_data.describe()
# Out:
#               price      order_id  order_details_id      quantity  \
# count  48620.000000  48620.000000      48620.000000  48620.000000
# mean      16.494132  10701.479761      24310.500000      1.019622
# std        3.621789   6180.119770      14035.529381      0.143077
# min        9.750000      1.000000          1.000000      1.000000
# 25%       12.750000   5337.000000      12155.750000      1.000000
# 50%       16.500000  10682.500000      24310.500000      1.000000
# 75%       20.250000  16100.000000      36465.250000      1.000000
# max       35.950000  21350.000000      48620.000000      4.000000
#
#             revenue
# count  48620.000000
# mean      16.821474
# std        4.437398
# min        9.750000
# 25%       12.750000
# 50%       16.500000
# 75%       20.500000
# max       83.000000

# %% [markdown]
# ## 💡 QUESTION 5

# %%
#Find the average price of the pizzas
avg_price = merged_data['price'].mean().round(3)

print('The average price of the pizzas:', avg_price)
# Out:
# The average price of the pizzas: 16.494

# %%
#Find if there are any duplicated rows
print(merged_data.duplicated().sum())
# Out:
# 0

# %%
#Count the number of pizzas being bought by size
pizza_size_counts = merged_data['size'].value_counts()

pizza_size_counts
# Out:
# size
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: count, dtype: int64

# %%
#Find the most common size of pizza being boought 
most_common_size = pizza_size_counts.idxmax()

most_common_size
# Out:
# 'L'

# %% [markdown]
# ## 💡 QUESTION 8

# %%
#Count top 5 selling pizzas
Top_5_selling_pizzas = merged_data['name'].value_counts().head(5)

Top_5_selling_pizzas
# Out:
# name
# The Classic Deluxe Pizza      2416
# The Barbecue Chicken Pizza    2372
# The Hawaiian Pizza            2370
# The Pepperoni Pizza           2369
# The Thai Chicken Pizza        2315
# Name: count, dtype: int64

# %%
#Create a pie plot to group the top 5 selling pizzas
best_5_selling_pizzas = merged_data['name'].value_counts().head(5)
best_5_selling_pizzas.plot.pie(autopct='%1.1f%%')
plt.title('Best 5 Selling Pizzas')
plt.ylabel('')
plt.show()

# %%
#Convert date and time to datetime and extract date, time, month, hours and day
merged_data['date'] = pd.to_datetime(merged_data['date'])
merged_data['time'] = pd.to_datetime(merged_data['time'])
merged_data['month'] = merged_data['date'].dt.month
merged_data['hour'] = merged_data['time'].dt.hour
merged_data['monthname'] = merged_data['date'].dt.month_name().str[:3]
merged_data['day'] = merged_data['date'].dt.day_name().str[:3]

merged_data
# Out:
#            pizza_id pizza_type_id size  price  \
# 0         bbq_ckn_l       bbq_ckn    L  20.75
# 1         bbq_ckn_l       bbq_ckn    L  20.75
# 2         bbq_ckn_l       bbq_ckn    L  20.75
# 3         bbq_ckn_l       bbq_ckn    L  20.75
# 4         bbq_ckn_l       bbq_ckn    L  20.75
# ...             ...           ...  ...    ...
# 48620  veggie_veg_s    veggie_veg    S  12.00
# 48621  veggie_veg_s    veggie_veg    S  12.00
# 48622  veggie_veg_s    veggie_veg    S  12.00
# 48623  veggie_veg_s    veggie_veg    S  12.00
# 48624  veggie_veg_s    veggie_veg    S  12.00
#
#                                     name category  \
# 0             The Barbecue Chicken Pizza  Chicken
# 1             The Barbecue Chicken Pizza  Chicken
# 2             The Barbecue Chicken Pizza  Chicken
# 3             The Barbecue Chicken Pizza  Chicken
# 4             The Barbecue Chicken Pizza  Chicken
# ...                                  ...      ...
# 48620  The Vegetables + Vegetables Pizza   Veggie
# ...

# %% [markdown]
# ## 💡 QUESTION 9

# %%
#Group revenue by month
revenue_by_month_name = merged_data.groupby('monthname')['revenue'].sum()
revenue_by_month_name
# Out:
# monthname
# Apr    68736.80
# Aug    68278.25
# Dec    64701.15
# Feb    65159.60
# Jan    69793.30
# Jul    72557.90
# Jun    68230.20
# Mar    70397.10
# May    71402.75
# Nov    70395.35
# Oct    64027.60
# Sep    64180.05
# Name: revenue, dtype: float64

# %%
revenue_by_month_name.idxmax()
# Out:
# 'Jul'

# %%
#creating a bar plot to group for the sales made each month

x = revenue_by_month_name.index
y = revenue_by_month_name.values
plt.bar(x,y,) 
plt.title('Revenue By Month')
plt.xlabel('Month')
plt.ylabel('Revenue')

#Saving the bar plot as a png file
plt.savefig('revenue_by_month_bar_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#creating a line plot to compare the sales made each month

plt.plot(revenue_by_month_name.index, revenue_by_month_name.values, color= 'blue', marker= 'o')
plt.title('Revenue By Month')
plt.xlabel('Month')
plt.ylabel('Revenue')

plt.savefig('revenue_by_month_line_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### ✨- From the 2 plots shown above, it is evident that the month of July has the most sales

# %%
#Get a description of the modified dataframe
merged_data.describe()
# Out:
#               price      order_id                           date  \
# count  48620.000000  48620.000000                          48620
# mean      16.494132  10701.479761  2015-06-29 11:03:43.611682560
# min        9.750000      1.000000            2015-01-01 00:00:00
# 25%       12.750000   5337.000000            2015-03-31 00:00:00
# 50%       16.500000  10682.500000            2015-06-28 00:00:00
# 75%       20.250000  16100.000000            2015-09-28 00:00:00
# max       35.950000  21350.000000            2015-12-31 00:00:00
# std        3.621789   6180.119770                            NaN
#
#                                 time  order_details_id      quantity  \
# count                          48620      48620.000000  48620.000000
# mean   2025-05-11 16:24:51.322151168      24310.500000      1.019622
# min              2025-05-11 09:52:21          1.000000      1.000000
# 25%              2025-05-11 13:24:46      12155.750000      1.000000
# ...

# %% [markdown]
# ## 💡 QUESTION 7

# %%
#Find the total sales made on each day of week
revenue_by_day_name = merged_data.groupby('day')['revenue'].sum()
revenue_by_day_name
# Out:
# day
# Fri    136073.90
# Mon    107329.55
# Sat    123182.40
# Sun     99203.50
# Thu    123528.50
# Tue    114133.80
# Wed    114408.40
# Name: revenue, dtype: float64

# %%
#Create a bar plot to show the days against the total sales

x = revenue_by_day_name.index
y = revenue_by_day_name.values
plt.bar(x,y,) 
plt.title('Revenue By Day')
plt.xlabel('Day')
plt.ylabel('Revenue')

plt.savefig('revenue_by_day_bar_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#Find the day of the week when sales are made the most
revenue_by_day_name.idxmax()
# Out:
# 'Fri'

# %%
#creating a line plot to compare the sales made each day

plt.plot(revenue_by_day_name.index, revenue_by_day_name.values, color= 'blue', marker= 'o')
plt.title('Revenue By Day')
plt.xlabel('Day')
plt.ylabel('Revenue')

plt.savefig('revenue_by_day_ine_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### ✨ It is seen from above that, Fridays are when sales are made the most, whiles there are low sales on Sundays

# %% [markdown]
# ### Group By Type and Revenue

# %%
#Group the dataframe by pizza type and revenue
revenue_by_name = merged_data.groupby('name')['revenue'].sum()
revenue_by_name
# Out:
# name
# The Barbecue Chicken Pizza                    42768.00
# The Big Meat Pizza                            22968.00
# The Brie Carre Pizza                          11588.50
# The Calabrese Pizza                           15934.25
# The California Chicken Pizza                  41409.50
# The Chicken Alfredo Pizza                     16900.25
# The Chicken Pesto Pizza                       16701.75
# The Classic Deluxe Pizza                      38180.50
# The Five Cheese Pizza                         26066.50
# The Four Cheese Pizza                         32265.70
# The Greek Pizza                               28454.10
# The Green Garden Pizza                        13955.75
# The Hawaiian Pizza                            32273.25
# The Italian Capocollo Pizza                   25094.00
# The Italian Supreme Pizza                     33476.75
# The Italian Vegetables Pizza                  16019.25
# The Mediterranean Pizza                       15360.50
# ...

# %%
#Find the pizza type is doing well
revenue_by_name.idxmax()
# Out:
# 'The Thai Chicken Pizza'

# %% [markdown]
# ## 💡 QUESTION 10

# %%
#Find the pizza type that is not doing well
revenue_by_name.idxmin()
print(f"The pizza type that is not doing well is {revenue_by_name.idxmin()}")
# Out:
# The pizza type that is not doing well is The Brie Carre Pizza

# %% [markdown]
# ## 💡 QUESTION 6

# %%
#Group the dataframe by hour and revenue to find how much sales is made each hour
revenue_by_hour = merged_data.groupby('hour')['revenue'].sum().reset_index()

revenue_by_hour
# Out:
#     hour    revenue
# 0      9      83.00
# 1     10     303.65
# 2     11   44935.80
# 3     12  111877.90
# 4     13  106065.70
# 5     14   59201.40
# 6     15   52992.30
# 7     16   70055.40
# 8     17   86237.45
# 9     18   89296.85
# 10    19   72628.90
# 11    20   58215.40
# 12    21   42029.80
# 13    22   22815.15
# 14    23    1121.35

# %%
#Find the peak hour of sales
peak_hour = merged_data.groupby('hour')['revenue'].sum().idxmax()

peak_hour
# Out:
# 12

# %%
#Find the hour where low sales are made
low_sales_hour = merged_data.groupby('hour')['revenue'].sum().idxmin()

low_sales_hour
# Out:
# 9

# %%
#Create a line plot to show the peak hour of sales

plt.plot(revenue_by_hour['hour'], revenue_by_hour['revenue'], color= 'blue', marker= 'o')
plt.title('Sales Made Per Hour')
plt.xlabel('Hour')
plt.ylabel('Revenue')

#Save the line plot as a PDF file
plt.savefig('revenue_by_hour_line_plot.pdf', dpi=300, bbox_inches='tight')
#Save the line plot as a png file
plt.savefig('revenue_by_hour_line_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### ✨ From the graph above, it shows that the peak hour of sales is 12, and the least is 9.

# %% [markdown]
# ### Group By Size and Revenue

# %%
#Group the dataframe by pizza size and revenue 
revenue_by_size = merged_data.groupby('size')['revenue'].sum()
revenue_by_size
# Out:
# size
# L      375318.70
# M      249382.25
# S      178076.50
# XL      14076.00
# XXL      1006.60
# Name: revenue, dtype: float64

# %%
#Plot a bar chart for pizza type and revenue

x = revenue_by_size.index
y = revenue_by_size.values
plt.bar(x,y,) 
plt.title('Revenue By Size')
plt.xlabel('Size')
plt.ylabel('Revenue')

plt.savefig('revenue_by_size_bar_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ##### ✨ From the graph above, it shows that the pizza type(large) is the most bought pizza type, and XXl is the least bought
